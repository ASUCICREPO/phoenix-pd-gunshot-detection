# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("GunShotURL.xlsx")
# Out:
# D:\Anaconda\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.rename(columns = {'Type of Sound (Gunshot, Unclear, etc.)':'Class'}, inplace = True)

# %%
for index, row in df.iterrows():
    if row['Class'] == "Possible Gunshot" or row['Class'] == "Gunshot" :
        df.at[index,'Class'] = "Gunshot"
    else :
        df.at[index,'Class'] = "Not Gunshot"

# %%
df
# Out:
#            Date Time (GMT)  Unnamed: 2  \
# 0    2022-06-29   00:59:58       88244
# 1    2022-06-29   15:30:09       88244
# 2    2022-06-29   15:34:39       88244
# 3    2022-06-29   15:50:33       88244
# 4    2022-06-29   17:03:12       88244
# ...         ...        ...         ...
# 4700 2022-08-01   02:03:12       88244
# 4701 2022-08-01   02:08:10       88244
# 4702 2022-08-01   03:37:25       88244
# 4703 2022-08-01   03:49:59       88244
# 4704 2022-08-01   04:08:51       88244
#
#                                       File name  \
# 0       Sample-1 (Tue Jun 28 17:59:55 2022).wav
# 1       Sample-1 (Wed Jun 29 08:30:07 2022).wav
# 2       Sample-2 (Wed Jun 29 08:34:37 2022).wav
# 3       Sample-3 (Wed Jun 29 08:50:31 2022).wav
# 4       Sample-3 (Wed Jun 29 10:03:10 2022).wav
# ...                                         ...
# 4700  Sample-402 (Sun Jul 31 19:03:10 2022).wav
# 4701  Sample-403 (Sun Jul 31 19:08:08 2022).wav
# 4702  Sample-404 (Sun Jul 31 20:37:23 2022).wav
# ...

# %%
print(df['Class'].unique())
# Out:
# ['Gunshot' 'Not Gunshot']

# %%
df['Class'].value_counts()
# Out:
# Not Gunshot    4567
# Gunshot         138
# Name: Class, dtype: int64

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['Class'])
print(one_hot_encoded_data)
# Out:
#            Date Time (GMT)  Unnamed: 2  \
# 0    2022-06-29   00:59:58       88244
# 1    2022-06-29   15:30:09       88244
# 2    2022-06-29   15:34:39       88244
# 3    2022-06-29   15:50:33       88244
# 4    2022-06-29   17:03:12       88244
# ...         ...        ...         ...
# 4700 2022-08-01   02:03:12       88244
# 4701 2022-08-01   02:08:10       88244
# 4702 2022-08-01   03:37:25       88244
# 4703 2022-08-01   03:49:59       88244
# 4704 2022-08-01   04:08:51       88244
#
#                                       File name  \
# 0       Sample-1 (Tue Jun 28 17:59:55 2022).wav
# 1       Sample-1 (Wed Jun 29 08:30:07 2022).wav
# 2       Sample-2 (Wed Jun 29 08:34:37 2022).wav
# 3       Sample-3 (Wed Jun 29 08:50:31 2022).wav
# 4       Sample-3 (Wed Jun 29 10:03:10 2022).wav
# ...                                         ...
# 4700  Sample-402 (Sun Jul 31 19:03:10 2022).wav
# 4701  Sample-403 (Sun Jul 31 19:08:08 2022).wav
# 4702  Sample-404 (Sun Jul 31 20:37:23 2022).wav
# ...

# %%
one_hot_encoded_data.to_excel("Gunshotencoded.xlsx")

# %%
import wget

for index, row in one_hot_encoded_data.iterrows():
    URL = row['File URL']
    fileName = str(index) + '.wav'
    response = wget.download(URL, fileName)
# Out:
# 100% [..............................................................................] 88244 / 88244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-8b655a425ada> in <module>
#       4     URL = row['File URL']
#       5     fileName = str(index) + '.wav'
# ----> 6     response = wget.download(URL, fileName)
#
# D:\Anaconda\lib\site-packages\wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# D:\Anaconda\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...
